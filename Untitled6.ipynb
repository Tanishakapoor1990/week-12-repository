# %%
import pandas as pd
df = pd.read_csv('loans_full_schema.csv')
df
# Out:
#                     emp_title  emp_length state homeownership  annual_income  \
# 0     global config engineer          3.0    NJ      MORTGAGE        90000.0
# 1      warehouse office clerk        10.0    HI          RENT        40000.0
# 2                    assembly         3.0    WI          RENT        40000.0
# 3            customer service         1.0    PA          RENT        30000.0
# 4        security supervisor         10.0    CA          RENT        35000.0
# ...                       ...         ...   ...           ...            ...
# 9995                   owner         10.0    TX          RENT       108000.0
# 9996                 director         8.0    PA      MORTGAGE       121000.0
# 9997                toolmaker        10.0    CT      MORTGAGE        67000.0
# 9998                  manager         1.0    WI      MORTGAGE        80000.0
# 9999       operations analyst         3.0    CT          RENT        66000.0
#
# ...

# %%
df.loc[:,['emp_title','emp_length']].isnull().mean()* 100
# Out:
# emp_title     8.33
# emp_length    8.17
# dtype: float64

# %% [markdown]
# ## First feature with missing values is emp_title.
# #I believe a good way to impute these values is with "Job title not given"

# %%
import numpy as np 
df['emp_title'] = np.where(df['emp_title'].isnull(),'Job title not given', df['emp_title'])
df['emp_title']
# Out:
# 0       global config engineer
# 1        warehouse office clerk
# 2                      assembly
# 3              customer service
# 4          security supervisor
#                  ...
# 9995                     owner
# 9996                   director
# 9997                  toolmaker
# 9998                    manager
# 9999         operations analyst
# Name: emp_title, Length: 10000, dtype: object

# %%
filt = (df['emp_title'] ==  "Job title not given")
df.loc[filt]
# Out:
#                 emp_title  emp_length state homeownership  annual_income  \
# 5     Job title not given         NaN    KY           OWN        34000.0
# 14    Job title not given         NaN    FL      MORTGAGE        17000.0
# 16    Job title not given         NaN    NV      MORTGAGE        60000.0
# 23    Job title not given         NaN    TX      MORTGAGE        40280.0
# 40    Job title not given         NaN    MI      MORTGAGE        19000.0
# ...                   ...         ...   ...           ...            ...
# 9912  Job title not given         NaN    MO           OWN        45000.0
# 9932  Job title not given         NaN    NC          RENT        45000.0
# 9941  Job title not given         NaN    GA      MORTGAGE        25000.0
# 9975  Job title not given         NaN    MD      MORTGAGE        95000.0
# 9976  Job title not given         NaN    MI      MORTGAGE        90000.0
#
#       verified_income  debt_to_income  annual_income_joint  \
# ...

# %%
df['months_since_last_delinq'].max()
# Out:
# 118.0

# %%
df['months_since_last_delinq'] = np.where(df['months_since_last_delinq'].isnull(),118,  df['months_since_last_delinq'])
df['months_since_last_delinq']
# Out:
# 0        38.0
# 1       118.0
# 2        28.0
# 3       118.0
# 4       118.0
#         ...
# 9995    118.0
# 9996      9.0
# 9997      6.0
# 9998    118.0
# 9999    118.0
# Name: months_since_last_delinq, Length: 10000, dtype: float64

# %%
df.isnull().mean()*100
# Out:
# emp_title                            0.00
# emp_length                           8.17
# state                                0.00
# homeownership                        0.00
# annual_income                        0.00
# verified_income                      0.00
# debt_to_income                       0.24
# annual_income_joint                 85.05
# verification_income_joint           85.45
# debt_to_income_joint                85.05
# delinq_2y                            0.00
# months_since_last_delinq             0.00
# earliest_credit_line                 0.00
# inquiries_last_12m                   0.00
# total_credit_lines                   0.00
# open_credit_lines                    0.00
# total_credit_limit                   0.00
# total_credit_utilized                0.00
# num_collections_last_12m             0.00
# num_historical_failed_to_pay         0.00
# months_since_90d_late               77.15
# current_accounts_delinq              0.00
# ...

# %% [markdown]
# ## features below are being dropped due to their significantly high proportion of missing values or they are date values.

# %%
drop_df = df.drop(['annual_income_joint', 'verification_income_joint', 'debt_to_income_joint', 'months_since_90d_late','months_since_last_credit_inquiry','num_accounts_120d_past_due'],axis=1)
drop_df
# Out:
#                     emp_title  emp_length state homeownership  annual_income  \
# 0     global config engineer          3.0    NJ      MORTGAGE        90000.0
# 1      warehouse office clerk        10.0    HI          RENT        40000.0
# 2                    assembly         3.0    WI          RENT        40000.0
# 3            customer service         1.0    PA          RENT        30000.0
# 4        security supervisor         10.0    CA          RENT        35000.0
# ...                       ...         ...   ...           ...            ...
# 9995                   owner         10.0    TX          RENT       108000.0
# 9996                 director         8.0    PA      MORTGAGE       121000.0
# 9997                toolmaker        10.0    CT      MORTGAGE        67000.0
# 9998                  manager         1.0    WI      MORTGAGE        80000.0
# 9999       operations analyst         3.0    CT          RENT        66000.0
#
# ...

# %%
df
# Out:
#                     emp_title  emp_length state homeownership  annual_income  \
# 0     global config engineer          3.0    NJ      MORTGAGE        90000.0
# 1      warehouse office clerk        10.0    HI          RENT        40000.0
# 2                    assembly         3.0    WI          RENT        40000.0
# 3            customer service         1.0    PA          RENT        30000.0
# 4        security supervisor         10.0    CA          RENT        35000.0
# ...                       ...         ...   ...           ...            ...
# 9995                   owner         10.0    TX          RENT       108000.0
# 9996                 director         8.0    PA      MORTGAGE       121000.0
# 9997                toolmaker        10.0    CT      MORTGAGE        67000.0
# 9998                  manager         1.0    WI      MORTGAGE        80000.0
# 9999       operations analyst         3.0    CT          RENT        66000.0
#
# ...

# %%
drop_df.isnull().mean()
# Out:
# emp_title                       0.0000
# emp_length                      0.0817
# state                           0.0000
# homeownership                   0.0000
# annual_income                   0.0000
# verified_income                 0.0000
# debt_to_income                  0.0024
# delinq_2y                       0.0000
# months_since_last_delinq        0.0000
# earliest_credit_line            0.0000
# inquiries_last_12m              0.0000
# total_credit_lines              0.0000
# open_credit_lines               0.0000
# total_credit_limit              0.0000
# total_credit_utilized           0.0000
# num_collections_last_12m        0.0000
# num_historical_failed_to_pay    0.0000
# current_accounts_delinq         0.0000
# total_collection_amount_ever    0.0000
# current_installment_accounts    0.0000
# accounts_opened_24m             0.0000
# num_satisfactory_accounts       0.0000
# num_accounts_30d_past_due       0.0000
# num_active_debit_accounts       0.0000
# ...

# %%
drop_df['interest_rate'].head()
# Out:
# 0    14.07
# 1    12.61
# 2    17.09
# 3     6.72
# 4    14.07
# Name: interest_rate, dtype: float64

# %%
filt= drop_df['emp_title']=="Job title not given"
drop_df.loc[filt]
# Out:
#                 emp_title  emp_length state homeownership  annual_income  \
# 5     Job title not given         NaN    KY           OWN        34000.0
# 14    Job title not given         NaN    FL      MORTGAGE        17000.0
# 16    Job title not given         NaN    NV      MORTGAGE        60000.0
# 23    Job title not given         NaN    TX      MORTGAGE        40280.0
# 40    Job title not given         NaN    MI      MORTGAGE        19000.0
# ...                   ...         ...   ...           ...            ...
# 9912  Job title not given         NaN    MO           OWN        45000.0
# 9932  Job title not given         NaN    NC          RENT        45000.0
# 9941  Job title not given         NaN    GA      MORTGAGE        25000.0
# 9975  Job title not given         NaN    MD      MORTGAGE        95000.0
# 9976  Job title not given         NaN    MI      MORTGAGE        90000.0
#
#       verified_income  debt_to_income  delinq_2y  months_since_last_delinq  \
# ...

# %%
filt= df['emp_title']=="Job title not given"
df.loc[filt]
# Out:
#                 emp_title  emp_length state homeownership  annual_income  \
# 5     Job title not given         NaN    KY           OWN        34000.0
# 14    Job title not given         NaN    FL      MORTGAGE        17000.0
# 16    Job title not given         NaN    NV      MORTGAGE        60000.0
# 23    Job title not given         NaN    TX      MORTGAGE        40280.0
# 40    Job title not given         NaN    MI      MORTGAGE        19000.0
# ...                   ...         ...   ...           ...            ...
# 9912  Job title not given         NaN    MO           OWN        45000.0
# 9932  Job title not given         NaN    NC          RENT        45000.0
# 9941  Job title not given         NaN    GA      MORTGAGE        25000.0
# 9975  Job title not given         NaN    MD      MORTGAGE        95000.0
# 9976  Job title not given         NaN    MI      MORTGAGE        90000.0
#
#       verified_income  debt_to_income  annual_income_joint  \
# ...

# %%
loans_df=drop_df.drop(['emp_length_redefined'],axis=1)

# %%
loans_df
# Out:
#                     emp_title emp_length state homeownership  annual_income  \
# 0     global config engineer         NaN    NJ      MORTGAGE        90000.0
# 1      warehouse office clerk        NaN    HI          RENT        40000.0
# 2                    assembly        NaN    WI          RENT        40000.0
# 3            customer service        NaN    PA          RENT        30000.0
# 4        security supervisor         NaN    CA          RENT        35000.0
# ...                       ...        ...   ...           ...            ...
# 9995                   owner         NaN    TX          RENT       108000.0
# 9996                 director        NaN    PA      MORTGAGE       121000.0
# 9997                toolmaker        NaN    CT      MORTGAGE        67000.0
# 9998                  manager        NaN    WI      MORTGAGE        80000.0
# 9999       operations analyst        NaN    CT          RENT        66000.0
#
# ...

# %%
df.isnull().mean()*100
# Out:
# emp_title                            0.00
# emp_length                           0.00
# state                                0.00
# homeownership                        0.00
# annual_income                        0.00
# verified_income                      0.00
# debt_to_income                       0.24
# annual_income_joint                 85.05
# verification_income_joint           85.45
# debt_to_income_joint                85.05
# delinq_2y                            0.00
# months_since_last_delinq             0.00
# earliest_credit_line                 0.00
# inquiries_last_12m                   0.00
# total_credit_lines                   0.00
# open_credit_lines                    0.00
# total_credit_limit                   0.00
# total_credit_utilized                0.00
# num_collections_last_12m             0.00
# num_historical_failed_to_pay         0.00
# months_since_90d_late               77.15
# current_accounts_delinq              0.00
# ...

# %%
df
# Out:
#                     emp_title               emp_length state homeownership  \
# 0     global config engineer   global config engineer     NJ      MORTGAGE
# 1      warehouse office clerk   warehouse office clerk    HI          RENT
# 2                    assembly                 assembly    WI          RENT
# 3            customer service         customer service    PA          RENT
# 4        security supervisor      security supervisor     CA          RENT
# ...                       ...                      ...   ...           ...
# 9995                   owner                    owner     TX          RENT
# 9996                 director                 director    PA      MORTGAGE
# 9997                toolmaker                toolmaker    CT      MORTGAGE
# 9998                  manager                  manager    WI      MORTGAGE
# 9999       operations analyst       operations analyst    CT          RENT
#
# ...
